# %% [markdown]
# # Clasificación de Residuos — Modelo D2: EfficientNetV2B0 Head
#
# ---
#
# ## Contexto del Experimento
#
# Este notebook forma parte de una **serie de experimentos de Transfer Learning** que aplica la técnica de la tijera: partimos del modelo más complejo (D0) y reducimos progresivamente la cabeza para encontrar el punto óptimo de simplicidad sin perder rendimiento.
#
# ### Estrategia Experimental
#
# - **Punto de partida**: D1 (GAP → Dense(256) → Dropout(0.4)) — F1=0.8874
# - **Enfoque**: ¿Reducir la capa densa a la mitad (256 → 128 neuronas) mejora o empeora?
# - **Observable**: Impacto de reducir capacidad de la cabeza manteniendo la estructura
#
# Cada modelo se implementa en un archivo independiente dentro de la carpeta `models/` del proyecto.
#
# ---
#
# ## Arquitectura del Modelo D2
#
# ### Descripción
#
# **EfficientNetV2B0 Head** reduce la capa densa intermedia de 256 a 128 neuronas respecto a D1, con Dropout(0.3). El backbone EfficientNetV2B0 está completamente descongelado desde el inicio, con LR bajo para preservar los pesos preentrenados.
#
# ### Posición en la Serie Descendente
#
# | Componente | D1 (Anterior) | D2 (Este modelo) | D3 (Siguiente) |
# |------------|--------------|-----------------|----------------|
# | **Backbone** | EfficientNetV2B0 descongelado | EfficientNetV2B0 descongelado | EfficientNetV2B0 descongelado |
# | **Cabeza** | GAP → Dense(256) → Dropout(0.4) → softmax | GAP → Dense(128) → Dropout(0.3) → softmax | GAP → Dense(6) → Dropout(0.3) → softmax |
# | **Parámetros** | 6,248,790 | 6,084,054 | 5,927,040 |
#
# **Hipótesis**: Reducir la cabeza a 128 neuronas mantiene suficiente capacidad para combinar las features del backbone, con menos riesgo de sobreajuste que D1.
#
# ---
#
# ## Resumen resultado final rendimiento en el conjunto de test
#
# | Modelo | Parámetros | Accuracy | Precision | Recall | F1-Score |
# |--------|----------:|--------:|----------:|-------:|--------:|
# | A1 (SimpleCNN) | 210 | 0.4921 | 0.4257 | 0.4326 | 0.4150 |
# | A2 (CNN Small) | 1,094 | 0.6100 | 0.6600 | 0.5600 | 0.5700 |
# | A3 (CNN Medium) | 19,782 | 0.7263 | 0.7114 | 0.6884 | 0.6973 |
# | A4 (CNN Large) | 94,918 | 0.7816 | 0.7643 | 0.7741 | 0.7578 |
# | D0 (EffNet Full) | 6,253,910 | 0.9316 | 0.9199 | 0.9121 | 0.9139 |
# | D1 (EffNet Top) | 6,248,790 | 0.9132 | 0.8815 | 0.9026 | 0.8874 |
# | **D2 (EffNet Head)** | **6,084,054** | **0.9079** | **0.8797** | **0.9040** | **0.8871** |
#
# ### Rendimiento por clase (Test)
#
# | Clase | Precision | Recall | F1-Score | Support |
# |-------|----------:|-------:|---------:|--------:|
# | cardboard | 0.95 | 0.98 | 0.97 | 60 |
# | glass | 0.97 | 0.80 | 0.88 | 76 |
# | metal | 0.86 | 0.97 | 0.91 | 62 |
# | paper | 0.94 | 0.94 | 0.94 | 89 |
# | plastic | 0.93 | 0.88 | 0.90 | 73 |
# | trash | 0.63 | 0.85 | 0.72 | 20 |
#
# **Nota**: D2 obtiene prácticamente el mismo resultado que D1 (F1: 0.8874 → 0.8871) con la mitad de neuronas en la cabeza, lo que sugiere que la capacidad extra de D1 era innecesaria. Ambos quedan por debajo de D0 (0.9139), confirmando que la BatchNorm de D0 era el elemento clave. D3 explorará si simplificar aún más la cabeza a solo 6 neuronas mantiene o degrada el rendimiento.
#
# ---
#
# ## Implementación
#
# A continuación se entrena y evalúa el modelo D2 usando el pipeline estándar del proyecto.

# %% [markdown]
# ---
# ## 0. Configuración del entorno (Colab)

# %%
# Celda 1 — Limpieza y configuración GPU
import gc
import keras
keras.backend.clear_session()
gc.collect()

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"Memory growth activado en {len(gpus)} GPU(s)")

print(tf.__version__)
# Out:
# 2026-03-13 18:37:18.282173: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-13 18:37:18.308768: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-13 18:37:18.938283: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Memory growth activado en 1 GPU(s)
# 2.20.0

# %%
# ========================================
# 1. IMPORTS Y CONFIGURACION
# ========================================

import os
import sys
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import keras

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

# Agregar ruta del proyecto al path (carpeta padre de notebooks)
sys.path.insert(0, '..')

# Importar funciones de utilidad
from src.utils import initialize_project

# %% [markdown]
# ---
# ## 1. Carga de datos

# %%
# ========================================
# 2. CARGA DE DATOS Y CONFIGURACION
# ========================================

X_train, y_train, X_val, y_val, X_test, y_test, class_names = initialize_project()
# Out:
# Ejecutando en local
#
# Cargando datos desde: /home/gosacar/Profundo/notebooks/../data/processed/trashnet_224x224.npz
#   X.shape: (2527, 224, 224, 3)
#   y.shape: (2527,)
#   Clases: cardboard, glass, metal, paper, plastic, trash
#
# División estratificada (seed=44):
#   Train: 1768 imágenes (70%)
#   Val:   379 imágenes (15%)
#   Test:  380 imágenes (15%)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

SEED       = 44   # ← tu semilla
BATCH_SIZE = 32
NUM_CLASSES = len(class_names)

augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.05, 0.05),
], name='augmentation')

def make_dataset(X, y, training=False):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    if training:
        ds = ds.shuffle(len(X), seed=SEED)
        ds = ds.map(lambda x, y: (augmentation(x, training=True), y),
                    num_parallel_calls=tf.data.AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

ds_train = make_dataset(X_train, y_train, training=True)
ds_val   = make_dataset(X_val,   y_val)
ds_test  = make_dataset(X_test,  y_test)

print('Datasets listos')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773423444.295054 2847880 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12010 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Datasets listos

# %% [markdown]
# ---
# ## 2. Definición del modelo

# %%
# ── CAMBIAR ESTAS DOS LÍNEAS SEGÚN EL MODELO ─────────────────────────────
from models.D2_effnet_head import build_effnet_head as build_model

# Ejemplos para otros modelos:
# from A2_cnn_small        import build_cnn_small        as build_model
# from A3_cnn_medium       import build_cnn_medium       as build_model
# from A4_cnn_large        import build_cnn_large        as build_model
# from A5_D5_cnn_frontier  import build_cnn_frontier     as build_model
# from D4_effnet_minimal   import build_effnet_minimal   as build_model
# from D3_effnet_gap       import build_effnet_gap       as build_model
# from D2_effnet_head      import build_effnet_head      as build_model
# from D1_effnet_top       import build_effnet_top       as build_model
# from D0_effnet_full      import build_effnet_full      as build_model


model = build_model(input_shape=(224, 224, 3), num_classes=6)
model.summary()
# Out:
# Model: "D2_EffNet_Head"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b0 (Functional)  │ (None, 7, 7, 1280)     │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ GAP (GlobalAveragePooling2D)    │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_128 (Dense)               │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,084,054 (23.21 MB)
#  Trainable params: 6,023,446 (22.98 MB)
#  Non-trainable params: 60,608 (236.75 KB)

# %% [markdown]
# ---
# ## 3. Entrenamiento

# %%
HAS_PHASE2 = False                  
MODEL_NAME = 'D2_EffNet_Head'

cb_early_stop = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=30,                    
    restore_best_weights=True,
    mode='max',
    verbose=1
)

cb_reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5,
    patience=30, min_lr=1e-6, verbose=1)

cb_checkpoint = callbacks.ModelCheckpoint(
    filepath=f'best_{MODEL_NAME}_phase1.keras',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)

model.compile(
    optimizer=keras.optimizers.Adam(
        learning_rate=1e-5,         
        weight_decay=1e-4
    ),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_p1 = model.fit(
    ds_train,
    validation_data=ds_val,
    epochs=300,
    callbacks=[cb_early_stop, cb_reduce_lr, cb_checkpoint],
    verbose=1
)
# Out:
# Epoch 1/300
# 2026-03-13 18:37:39.808867: I external/local_xla/xla/service/service.cc:163] XLA service 0x716690017b10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-13 18:37:39.808884: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-03-13 18:37:40.339211: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-03-13 18:37:42.429143: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2026-03-13 18:37:43.716224: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-13 18:37:44.126275: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_24354', 520 bytes spill stores, 520 bytes spill loads
#
# 2026-03-13 18:37:45.968873: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:37:46.051200: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:37:46.329064: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:37:46.415172: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:37:46.848247: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:37:46.931403: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:37:49.923675: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:37:50.006792: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  3/56 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.1615 - loss: 1.8054
# I0000 00:00:1773423479.405136 2848026 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/56 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1671 - loss: 1.8065
# 2026-03-13 18:38:07.315386: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:07.397959: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:07.647585: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:07.733656: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:08.122177: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:08.204620: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.1675 - loss: 1.8061
# 2026-03-13 18:38:19.837835: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 432 bytes spill stores, 416 bytes spill loads
#
# 2026-03-13 18:38:21.435805: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2294', 20 bytes spill stores, 20 bytes spill loads
#
# 2026-03-13 18:38:24.671623: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:24.754625: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:25.031385: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:38:25.116554: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 60s 496ms/step - accuracy: 0.1867 - loss: 1.7852 - val_accuracy: 0.2216 - val_loss: 1.7689 - learning_rate: 1.0000e-05
# Epoch 2/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.2800 - loss: 1.6932 - val_accuracy: 0.2850 - val_loss: 1.7072 - learning_rate: 1.0000e-05
# Epoch 3/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.3671 - loss: 1.6134 - val_accuracy: 0.3536 - val_loss: 1.6351 - learning_rate: 1.0000e-05
# Epoch 4/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.4400 - loss: 1.5332 - val_accuracy: 0.4116 - val_loss: 1.5606 - learning_rate: 1.0000e-05
# Epoch 5/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.4994 - loss: 1.4470 - val_accuracy: 0.4934 - val_loss: 1.4846 - learning_rate: 1.0000e-05
# Epoch 6/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.5611 - loss: 1.3549 - val_accuracy: 0.5383 - val_loss: 1.4068 - learning_rate: 1.0000e-05
# Epoch 7/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.5854 - loss: 1.2815 - val_accuracy: 0.5620 - val_loss: 1.3287 - learning_rate: 1.0000e-05
# Epoch 8/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.6510 - loss: 1.1823 - val_accuracy: 0.6148 - val_loss: 1.2445 - learning_rate: 1.0000e-05
# Epoch 9/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.6499 - loss: 1.1063 - val_accuracy: 0.6491 - val_loss: 1.1587 - learning_rate: 1.0000e-05
# Epoch 10/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.6793 - loss: 1.0209 - val_accuracy: 0.6860 - val_loss: 1.0944 - learning_rate: 1.0000e-05
# Epoch 11/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7081 - loss: 0.9469 - val_accuracy: 0.7018 - val_loss: 1.0110 - learning_rate: 1.0000e-05
# Epoch 12/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7285 - loss: 0.8955 - val_accuracy: 0.7150 - val_loss: 0.9760 - learning_rate: 1.0000e-05
# Epoch 13/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7336 - loss: 0.8301 - val_accuracy: 0.7256 - val_loss: 0.9303 - learning_rate: 1.0000e-05
# Epoch 14/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7562 - loss: 0.7852 - val_accuracy: 0.7441 - val_loss: 0.8743 - learning_rate: 1.0000e-05
# Epoch 15/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7494 - loss: 0.7518 - val_accuracy: 0.7493 - val_loss: 0.8524 - learning_rate: 1.0000e-05
# Epoch 16/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.7596 - loss: 0.7272 - val_accuracy: 0.7573 - val_loss: 0.8180 - learning_rate: 1.0000e-05
# Epoch 17/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7919 - loss: 0.6586 - val_accuracy: 0.7546 - val_loss: 0.7956 - learning_rate: 1.0000e-05
# Epoch 18/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7907 - loss: 0.6476 - val_accuracy: 0.7889 - val_loss: 0.7570 - learning_rate: 1.0000e-05
# Epoch 19/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7952 - loss: 0.6171 - val_accuracy: 0.7678 - val_loss: 0.7541 - learning_rate: 1.0000e-05
# Epoch 20/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8060 - loss: 0.5839 - val_accuracy: 0.7784 - val_loss: 0.7217 - learning_rate: 1.0000e-05
# Epoch 21/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8066 - loss: 0.5731 - val_accuracy: 0.7863 - val_loss: 0.7323 - learning_rate: 1.0000e-05
# Epoch 22/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.8428 - loss: 0.5167 - val_accuracy: 0.8021 - val_loss: 0.6710 - learning_rate: 1.0000e-05
# Epoch 23/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.8394 - loss: 0.5021 - val_accuracy: 0.8127 - val_loss: 0.6721 - learning_rate: 1.0000e-05
# Epoch 24/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8371 - loss: 0.5007 - val_accuracy: 0.7995 - val_loss: 0.6596 - learning_rate: 1.0000e-05
# Epoch 25/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.8484 - loss: 0.4740 - val_accuracy: 0.8179 - val_loss: 0.6184 - learning_rate: 1.0000e-05
# Epoch 26/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8609 - loss: 0.4383 - val_accuracy: 0.8127 - val_loss: 0.6098 - learning_rate: 1.0000e-05
# Epoch 27/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8705 - loss: 0.4235 - val_accuracy: 0.8153 - val_loss: 0.6234 - learning_rate: 1.0000e-05
# Epoch 28/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.8626 - loss: 0.4118 - val_accuracy: 0.8311 - val_loss: 0.5879 - learning_rate: 1.0000e-05
# Epoch 29/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8773 - loss: 0.3886 - val_accuracy: 0.8232 - val_loss: 0.6042 - learning_rate: 1.0000e-05
# Epoch 30/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8784 - loss: 0.3842 - val_accuracy: 0.8232 - val_loss: 0.5863 - learning_rate: 1.0000e-05
# Epoch 31/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8846 - loss: 0.3636 - val_accuracy: 0.8285 - val_loss: 0.5660 - learning_rate: 1.0000e-05
# Epoch 32/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.8869 - loss: 0.3377 - val_accuracy: 0.8364 - val_loss: 0.5600 - learning_rate: 1.0000e-05
# Epoch 33/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8948 - loss: 0.3309 - val_accuracy: 0.8364 - val_loss: 0.5461 - learning_rate: 1.0000e-05
# Epoch 34/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9050 - loss: 0.3156 - val_accuracy: 0.8285 - val_loss: 0.5594 - learning_rate: 1.0000e-05
# Epoch 35/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8982 - loss: 0.3211 - val_accuracy: 0.8259 - val_loss: 0.5309 - learning_rate: 1.0000e-05
# Epoch 36/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9135 - loss: 0.2827 - val_accuracy: 0.8206 - val_loss: 0.5401 - learning_rate: 1.0000e-05
# Epoch 37/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9123 - loss: 0.2886 - val_accuracy: 0.8285 - val_loss: 0.5313 - learning_rate: 1.0000e-05
# Epoch 38/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9225 - loss: 0.2700 - val_accuracy: 0.8391 - val_loss: 0.5178 - learning_rate: 1.0000e-05
# Epoch 39/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9163 - loss: 0.2699 - val_accuracy: 0.8338 - val_loss: 0.5140 - learning_rate: 1.0000e-05
# Epoch 40/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9202 - loss: 0.2548 - val_accuracy: 0.8391 - val_loss: 0.5032 - learning_rate: 1.0000e-05
# Epoch 41/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9316 - loss: 0.2337 - val_accuracy: 0.8285 - val_loss: 0.5436 - learning_rate: 1.0000e-05
# Epoch 42/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9265 - loss: 0.2354 - val_accuracy: 0.8549 - val_loss: 0.4694 - learning_rate: 1.0000e-05
# Epoch 43/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9316 - loss: 0.2390 - val_accuracy: 0.8522 - val_loss: 0.4979 - learning_rate: 1.0000e-05
# Epoch 44/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9338 - loss: 0.2233 - val_accuracy: 0.8522 - val_loss: 0.4715 - learning_rate: 1.0000e-05
# Epoch 45/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9355 - loss: 0.2171 - val_accuracy: 0.8443 - val_loss: 0.5049 - learning_rate: 1.0000e-05
# Epoch 46/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9451 - loss: 0.1980 - val_accuracy: 0.8443 - val_loss: 0.4839 - learning_rate: 1.0000e-05
# Epoch 47/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9474 - loss: 0.1957 - val_accuracy: 0.8549 - val_loss: 0.4877 - learning_rate: 1.0000e-05
# Epoch 48/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9395 - loss: 0.1966 - val_accuracy: 0.8443 - val_loss: 0.5127 - learning_rate: 1.0000e-05
# Epoch 49/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9423 - loss: 0.1903 - val_accuracy: 0.8628 - val_loss: 0.4996 - learning_rate: 1.0000e-05
# Epoch 50/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9485 - loss: 0.1796 - val_accuracy: 0.8470 - val_loss: 0.4721 - learning_rate: 1.0000e-05
# Epoch 51/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9519 - loss: 0.1791 - val_accuracy: 0.8496 - val_loss: 0.4788 - learning_rate: 1.0000e-05
# Epoch 52/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9497 - loss: 0.1650 - val_accuracy: 0.8760 - val_loss: 0.4482 - learning_rate: 1.0000e-05
# Epoch 53/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9553 - loss: 0.1566 - val_accuracy: 0.8575 - val_loss: 0.4908 - learning_rate: 1.0000e-05
# Epoch 54/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9468 - loss: 0.1743 - val_accuracy: 0.8707 - val_loss: 0.4327 - learning_rate: 1.0000e-05
# Epoch 55/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9559 - loss: 0.1560 - val_accuracy: 0.8707 - val_loss: 0.4568 - learning_rate: 1.0000e-05
# Epoch 56/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9491 - loss: 0.1646 - val_accuracy: 0.8707 - val_loss: 0.4447 - learning_rate: 1.0000e-05
# Epoch 57/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9564 - loss: 0.1440 - val_accuracy: 0.8760 - val_loss: 0.4196 - learning_rate: 1.0000e-05
# Epoch 58/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9564 - loss: 0.1508 - val_accuracy: 0.8654 - val_loss: 0.4580 - learning_rate: 1.0000e-05
# Epoch 59/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9655 - loss: 0.1327 - val_accuracy: 0.8681 - val_loss: 0.4502 - learning_rate: 1.0000e-05
# Epoch 60/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9576 - loss: 0.1368 - val_accuracy: 0.8760 - val_loss: 0.4472 - learning_rate: 1.0000e-05
# Epoch 61/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9689 - loss: 0.1167 - val_accuracy: 0.8786 - val_loss: 0.4205 - learning_rate: 1.0000e-05
# Epoch 62/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9672 - loss: 0.1311 - val_accuracy: 0.8654 - val_loss: 0.4493 - learning_rate: 1.0000e-05
# Epoch 63/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9621 - loss: 0.1324 - val_accuracy: 0.8707 - val_loss: 0.4407 - learning_rate: 1.0000e-05
# Epoch 64/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9548 - loss: 0.1328 - val_accuracy: 0.8734 - val_loss: 0.4447 - learning_rate: 1.0000e-05
# Epoch 65/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9729 - loss: 0.1104 - val_accuracy: 0.8734 - val_loss: 0.4323 - learning_rate: 1.0000e-05
# Epoch 66/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9734 - loss: 0.1113 - val_accuracy: 0.8654 - val_loss: 0.4695 - learning_rate: 1.0000e-05
# Epoch 67/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9638 - loss: 0.1169 - val_accuracy: 0.8734 - val_loss: 0.4096 - learning_rate: 1.0000e-05
# Epoch 68/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9723 - loss: 0.1053 - val_accuracy: 0.8707 - val_loss: 0.4299 - learning_rate: 1.0000e-05
# Epoch 69/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9666 - loss: 0.1103 - val_accuracy: 0.8865 - val_loss: 0.3948 - learning_rate: 1.0000e-05
# Epoch 70/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9706 - loss: 0.1100 - val_accuracy: 0.8918 - val_loss: 0.3984 - learning_rate: 1.0000e-05
# Epoch 71/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9779 - loss: 0.0970 - val_accuracy: 0.8707 - val_loss: 0.4684 - learning_rate: 1.0000e-05
# Epoch 72/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9751 - loss: 0.0892 - val_accuracy: 0.8865 - val_loss: 0.3834 - learning_rate: 1.0000e-05
# Epoch 73/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9661 - loss: 0.1133 - val_accuracy: 0.8839 - val_loss: 0.4126 - learning_rate: 1.0000e-05
# Epoch 74/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9768 - loss: 0.0887 - val_accuracy: 0.8734 - val_loss: 0.4350 - learning_rate: 1.0000e-05
# Epoch 75/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9734 - loss: 0.0988 - val_accuracy: 0.8945 - val_loss: 0.3819 - learning_rate: 1.0000e-05
# Epoch 76/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9723 - loss: 0.0959 - val_accuracy: 0.8865 - val_loss: 0.4036 - learning_rate: 1.0000e-05
# Epoch 77/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9774 - loss: 0.0825 - val_accuracy: 0.8892 - val_loss: 0.3951 - learning_rate: 1.0000e-05
# Epoch 78/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9712 - loss: 0.0882 - val_accuracy: 0.8892 - val_loss: 0.3993 - learning_rate: 1.0000e-05
# Epoch 79/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9791 - loss: 0.0789 - val_accuracy: 0.8813 - val_loss: 0.4204 - learning_rate: 1.0000e-05
# Epoch 80/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9762 - loss: 0.0864 - val_accuracy: 0.8918 - val_loss: 0.4025 - learning_rate: 1.0000e-05
# Epoch 81/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9700 - loss: 0.0957 - val_accuracy: 0.8786 - val_loss: 0.4276 - learning_rate: 1.0000e-05
# Epoch 82/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9779 - loss: 0.0762 - val_accuracy: 0.8918 - val_loss: 0.3865 - learning_rate: 1.0000e-05
# Epoch 83/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9859 - loss: 0.0563 - val_accuracy: 0.8971 - val_loss: 0.4094 - learning_rate: 1.0000e-05
# Epoch 84/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9796 - loss: 0.0745 - val_accuracy: 0.8918 - val_loss: 0.3623 - learning_rate: 1.0000e-05
# Epoch 85/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9819 - loss: 0.0711 - val_accuracy: 0.8945 - val_loss: 0.3904 - learning_rate: 1.0000e-05
# Epoch 86/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9785 - loss: 0.0772 - val_accuracy: 0.8945 - val_loss: 0.4101 - learning_rate: 1.0000e-05
# Epoch 87/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9779 - loss: 0.0699 - val_accuracy: 0.9077 - val_loss: 0.3907 - learning_rate: 1.0000e-05
# Epoch 88/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9779 - loss: 0.0719 - val_accuracy: 0.8945 - val_loss: 0.3872 - learning_rate: 1.0000e-05
# Epoch 89/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9825 - loss: 0.0672 - val_accuracy: 0.8760 - val_loss: 0.4544 - learning_rate: 1.0000e-05
# Epoch 90/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9842 - loss: 0.0638 - val_accuracy: 0.8945 - val_loss: 0.4005 - learning_rate: 1.0000e-05
# Epoch 91/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9808 - loss: 0.0701 - val_accuracy: 0.8865 - val_loss: 0.4152 - learning_rate: 1.0000e-05
# Epoch 92/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9853 - loss: 0.0664 - val_accuracy: 0.8734 - val_loss: 0.4735 - learning_rate: 1.0000e-05
# Epoch 93/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9881 - loss: 0.0514 - val_accuracy: 0.8997 - val_loss: 0.3828 - learning_rate: 1.0000e-05
# Epoch 94/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9830 - loss: 0.0635 - val_accuracy: 0.9050 - val_loss: 0.4031 - learning_rate: 1.0000e-05
# Epoch 95/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9847 - loss: 0.0578 - val_accuracy: 0.8945 - val_loss: 0.4199 - learning_rate: 1.0000e-05
# Epoch 96/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9802 - loss: 0.0659 - val_accuracy: 0.8945 - val_loss: 0.4141 - learning_rate: 1.0000e-05
# Epoch 97/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9864 - loss: 0.0544 - val_accuracy: 0.8971 - val_loss: 0.4048 - learning_rate: 1.0000e-05
# Epoch 98/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9864 - loss: 0.0538 - val_accuracy: 0.8839 - val_loss: 0.4192 - learning_rate: 1.0000e-05
# Epoch 99/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9830 - loss: 0.0601 - val_accuracy: 0.8918 - val_loss: 0.4021 - learning_rate: 1.0000e-05
# Epoch 100/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9825 - loss: 0.0506 - val_accuracy: 0.8971 - val_loss: 0.3931 - learning_rate: 1.0000e-05
# Epoch 101/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9881 - loss: 0.0483 - val_accuracy: 0.8997 - val_loss: 0.3872 - learning_rate: 1.0000e-05
# Epoch 102/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9881 - loss: 0.0526 - val_accuracy: 0.9103 - val_loss: 0.3854 - learning_rate: 1.0000e-05
# Epoch 103/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9904 - loss: 0.0418 - val_accuracy: 0.8945 - val_loss: 0.3920 - learning_rate: 1.0000e-05
# Epoch 104/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9819 - loss: 0.0550 - val_accuracy: 0.9024 - val_loss: 0.3891 - learning_rate: 1.0000e-05
# Epoch 105/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9915 - loss: 0.0394 - val_accuracy: 0.8997 - val_loss: 0.4175 - learning_rate: 1.0000e-05
# Epoch 106/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9853 - loss: 0.0496 - val_accuracy: 0.9156 - val_loss: 0.3643 - learning_rate: 1.0000e-05
# Epoch 107/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9870 - loss: 0.0449 - val_accuracy: 0.9024 - val_loss: 0.3879 - learning_rate: 1.0000e-05
# Epoch 108/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9904 - loss: 0.0394 - val_accuracy: 0.9129 - val_loss: 0.3823 - learning_rate: 1.0000e-05
# Epoch 109/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9904 - loss: 0.0426 - val_accuracy: 0.9103 - val_loss: 0.3434 - learning_rate: 1.0000e-05
# Epoch 110/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9893 - loss: 0.0499 - val_accuracy: 0.9050 - val_loss: 0.3909 - learning_rate: 1.0000e-05
# Epoch 111/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9898 - loss: 0.0425 - val_accuracy: 0.9024 - val_loss: 0.3948 - learning_rate: 1.0000e-05
# Epoch 112/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9881 - loss: 0.0426 - val_accuracy: 0.8997 - val_loss: 0.3877 - learning_rate: 1.0000e-05
# Epoch 113/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9881 - loss: 0.0486 - val_accuracy: 0.9024 - val_loss: 0.3829 - learning_rate: 1.0000e-05
# Epoch 114/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9915 - loss: 0.0345 - val_accuracy: 0.9103 - val_loss: 0.3890 - learning_rate: 1.0000e-05
# Epoch 115/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9898 - loss: 0.0409 - val_accuracy: 0.9050 - val_loss: 0.4020 - learning_rate: 1.0000e-05
# Epoch 116/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9876 - loss: 0.0452 - val_accuracy: 0.9024 - val_loss: 0.3819 - learning_rate: 1.0000e-05
# Epoch 117/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9893 - loss: 0.0355 - val_accuracy: 0.8997 - val_loss: 0.3992 - learning_rate: 1.0000e-05
# Epoch 118/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9887 - loss: 0.0398 - val_accuracy: 0.8971 - val_loss: 0.4089 - learning_rate: 1.0000e-05
# Epoch 119/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9915 - loss: 0.0332 - val_accuracy: 0.9077 - val_loss: 0.3973 - learning_rate: 1.0000e-05
# Epoch 120/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9915 - loss: 0.0332 - val_accuracy: 0.9103 - val_loss: 0.3803 - learning_rate: 1.0000e-05
# Epoch 121/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9887 - loss: 0.0372 - val_accuracy: 0.9129 - val_loss: 0.3753 - learning_rate: 1.0000e-05
# Epoch 122/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9881 - loss: 0.0330 - val_accuracy: 0.9050 - val_loss: 0.3709 - learning_rate: 1.0000e-05
# Epoch 123/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9881 - loss: 0.0422 - val_accuracy: 0.9129 - val_loss: 0.3961 - learning_rate: 1.0000e-05
# Epoch 124/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9898 - loss: 0.0323 - val_accuracy: 0.9103 - val_loss: 0.3916 - learning_rate: 1.0000e-05
# Epoch 125/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9932 - loss: 0.0278 - val_accuracy: 0.8971 - val_loss: 0.4066 - learning_rate: 1.0000e-05
# Epoch 126/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9926 - loss: 0.0378 - val_accuracy: 0.9050 - val_loss: 0.4002 - learning_rate: 1.0000e-05
# Epoch 127/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9915 - loss: 0.0354 - val_accuracy: 0.9077 - val_loss: 0.3885 - learning_rate: 1.0000e-05
# Epoch 128/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9910 - loss: 0.0364 - val_accuracy: 0.9050 - val_loss: 0.3910 - learning_rate: 1.0000e-05
# Epoch 129/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9876 - loss: 0.0365 - val_accuracy: 0.9129 - val_loss: 0.3908 - learning_rate: 1.0000e-05
# Epoch 130/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9926 - loss: 0.0280 - val_accuracy: 0.8971 - val_loss: 0.4065 - learning_rate: 1.0000e-05
# Epoch 131/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9938 - loss: 0.0280 - val_accuracy: 0.9129 - val_loss: 0.3929 - learning_rate: 1.0000e-05
# Epoch 132/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9904 - loss: 0.0328 - val_accuracy: 0.8971 - val_loss: 0.4356 - learning_rate: 1.0000e-05
# Epoch 133/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9966 - loss: 0.0229 - val_accuracy: 0.9077 - val_loss: 0.3906 - learning_rate: 1.0000e-05
# Epoch 134/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9921 - loss: 0.0344 - val_accuracy: 0.8945 - val_loss: 0.4409 - learning_rate: 1.0000e-05
# Epoch 135/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9926 - loss: 0.0284 - val_accuracy: 0.8997 - val_loss: 0.4034 - learning_rate: 1.0000e-05
# Epoch 136/300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9915 - loss: 0.0317 - val_accuracy: 0.9050 - val_loss: 0.4115 - learning_rate: 1.0000e-05
# Epoch 136: early stopping
# Restoring model weights from the end of the best epoch: 106.

# %% [markdown]
# ---
# ## 4. Curvas de entrenamiento

# %%
def smooth(values, weight=0.85):
    """Suavizado exponencial (similar a TensorBoard)."""
    smoothed, last = [], values[0]
    for v in values:
        last = last * weight + (1 - weight) * v
        smoothed.append(last)
    return smoothed


def plot_training(history, title='', phase=1):
    loss     = history.history['loss']
    val_loss = history.history['val_loss']
    acc      = history.history['accuracy']
    val_acc  = history.history['val_accuracy']
    epochs   = range(1, len(loss) + 1)

    fig, axes = plt.subplots(1, 2, figsize=(18, 10))
    fig.suptitle(f'{title} — Fase {phase}', fontsize=14, fontweight='bold')

    # ── Fila 1: Loss ─────────────────────────────────────────────────────────
    # 1a) Curva completa
    axes[0].plot(epochs, loss,     label='Train')
    axes[0].plot(epochs, val_loss, label='Validación')
    axes[0].set_title('Loss — Completa')
    axes[0].set_xlabel('Época'); axes[0].set_ylabel('Loss')
    axes[0].legend()

    # ── Fila 2: Accuracy ─────────────────────────────────────────────────────
    axes[1].plot(epochs, acc,     label='Train')
    axes[1].plot(epochs, val_acc, label='Validación')
    axes[1].set_title('Accuracy — Completa')
    axes[1].set_xlabel('Época'); axes[1].set_ylabel('Accuracy')
    axes[1].legend()


    plt.tight_layout()
    plt.savefig(f'curvas_{MODEL_NAME}_fase{phase}.png', dpi=150)
    plt.show()


plot_training(history_p1, title=MODEL_NAME, phase=1)

# %% [markdown]
# ---
# ## 5. Evaluación — Train / Val / Test

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_split(model, X, y, split_name):
    """Calcula y muestra Accuracy, Precision, Recall y F1-macro."""
    y_pred = np.argmax(model.predict(X, verbose=0), axis=1)
    acc  = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, average='macro', zero_division=0)
    rec  = recall_score(y, y_pred, average='macro', zero_division=0)
    f1   = f1_score(y, y_pred, average='macro', zero_division=0)
    print(f'[{split_name:>5}]  Acc={acc:.4f}  Prec={prec:.4f}  '
          f'Rec={rec:.4f}  F1={f1:.4f}')
    return {'split': split_name, 'acc': acc,
            'prec': prec, 'rec': rec, 'f1': f1, 'y_pred': y_pred}

print('-' * 60)
print(f'Modelo: {MODEL_NAME}')
print('-' * 60)
res_train = evaluate_split(model, X_train, y_train, 'Train')
res_val   = evaluate_split(model, X_val,   y_val,   'Val')
res_test  = evaluate_split(model, X_test,  y_test,  'Test')
print('-' * 60)
# Out:
# ------------------------------------------------------------
# Modelo: D2_EffNet_Head
# ------------------------------------------------------------
# [Train]  Acc=0.9870  Prec=0.9761  Rec=0.9892  F1=0.9821
# [  Val]  Acc=0.9156  Prec=0.9006  Rec=0.9172  F1=0.9050
# 2026-03-13 18:47:00.407915: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:47:00.490346: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:47:00.768690: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-13 18:47:00.855390: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# [ Test]  Acc=0.8947  Prec=0.8704  Rec=0.8928  F1=0.8766
# ------------------------------------------------------------

# %%
# ── Número de parámetros (para la tabla del README) ──────────────────────────
total_params     = model.count_params()
trainable_params = sum([tf.size(w).numpy() for w in model.trainable_weights])

print(f'Parámetros totales    : {total_params:,}')
print(f'Parámetros entrenables: {trainable_params:,}')
# Out:
# Parámetros totales    : 6,084,054
# Parámetros entrenables: 6,023,446

# %% [markdown]
# ---
# ## 6. Matriz de confusión

# %%
import seaborn as sns

def plot_confusion_matrix(y_true, y_pred, title='Test'):
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f'Matriz de Confusión — {title}', fontweight='bold')

    for ax, data, fmt, ttl in zip(
        axes,
        [cm, cm_norm],
        ['d', '.2f'],
        ['Absoluta', 'Normalizada']
    ):
        sns.heatmap(data, annot=True, fmt=fmt, cmap='Blues',
                    xticklabels=class_names, yticklabels=class_names, ax=ax)
        ax.set_title(ttl)
        ax.set_xlabel('Predicho')
        ax.set_ylabel('Real')

    plt.tight_layout()
    plt.savefig(f'confusion_{MODEL_NAME}.png', dpi=150)
    plt.show()


plot_confusion_matrix(y_test, res_test['y_pred'], title=f'{MODEL_NAME} — Test')
print(classification_report(y_test, res_test['y_pred'],
                             target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#    cardboard       0.92      0.98      0.95        60
#        glass       0.98      0.78      0.87        76
#        metal       0.83      0.95      0.89        62
#        paper       0.93      0.93      0.93        89
#      plastic       0.90      0.86      0.88        73
#        trash       0.65      0.85      0.74        20
#
#     accuracy                           0.89       380
#    macro avg       0.87      0.89      0.88       380
# weighted avg       0.90      0.89      0.90       380

# %% [markdown]
# ---
# ## 7. Resumen

# %%
print('─' * 90)
for res in [res_train, res_val, res_test]:
    print(
        f"| **{MODEL_NAME}** | {total_params:,} | {res['split']:>5} "
        f"| {res['acc']:.4f} | {res['prec']:.4f} "
        f"| {res['rec']:.4f} | {res['f1']:.4f} |"
    )
print('─' * 90)
# Out:
# ──────────────────────────────────────────────────────────────────────────────────────────
# | **D2_EffNet_Head** | 6,084,054 | Train | 0.9870 | 0.9761 | 0.9892 | 0.9821 |
# | **D2_EffNet_Head** | 6,084,054 |   Val | 0.9156 | 0.9006 | 0.9172 | 0.9050 |
# | **D2_EffNet_Head** | 6,084,054 |  Test | 0.8947 | 0.8704 | 0.8928 | 0.8766 |
# ──────────────────────────────────────────────────────────────────────────────────────────
